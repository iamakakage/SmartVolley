# %%
import cv2
import glob
import natsort
import pickle
import imutils
import numpy as np

from utils.hdf5datasetwriter import HDF5DatasetWriter
from utils.aspect_aware_resize import AspectAwareResize

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_paths = natsort.natsorted(glob.glob("train/*.png"))
metadata = pickle.load(open("pkl/metadata.pkl", "rb"))

aar = AspectAwareResize(96, 96)

# %%
def imshow(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
def make_square(image):
    (h, w) = image.shape[:2]
    
    dH = 0
    dW = 0
    
    if h < w:
        dW = (w-h)//2
    elif w < h:
        dH = (h-w) // 2
        
    image = image[dH:h-dH, dW:w-dW]
        
    return image, dH, dW

# %%
def xywh_bbox(img, metadata):
    shape = img.shape[:2]
    
    x = int(min(metadata["left"]))
    y = int(min(metadata["top"]))
    w = int(metadata["left"][-1] + metadata["width"][-1])
    h = int(max(metadata["top"]) + max(metadata["height"]))
    
    return x, y, w-x, h-y

# %%
def aar_xywh(img, metadata, size=96):
    height, width = img.shape[:2]
    a = height if height < width else width

    img, dH, dW = make_square(img)

    x, y, w, h = xywh_bbox(img, metadata)

    x = x-dW
    y = y-dH

    x = int(x * (size/a))
    y = int(y * (size/a))
    w = int(w * (size/a))
    h = int(h * (size/a))
    return (x, y, w, h)

# %%
i = 6000

img1_meta = metadata[i]
img1 = cv2.imread(image_paths[i])

x, y, w, h = aar_xywh(img1, img1_meta)

img1 = aar.preprocess(img1)
cv2.rectangle(img1, (x, y), (x+w, y+h), (0, 255, 0), 2)

imshow(img1)

# %%
train_path = natsort.natsorted(glob.glob("train/*.png"))[:-2500]
train_meta = pickle.load(open("pkl/metadata.pkl", "rb"))[:-2500]
val_path = natsort.natsorted(glob.glob("train/*.png"))[-2500:]
val_meta = pickle.load(open("pkl/metadata.pkl", "rb"))[-2500:]
# extra_path = natsort.natsorted(glob.glob("extra/*.png"))
# extra_meta = pickle.load(open("pkl/metadata_extra.pkl", "rb"))
test_path = natsort.natsorted(glob.glob("test/*.png"))
test_meta = pickle.load(open("pkl/metadata_test.pkl", "rb"))

stuffs = [(train_path, train_meta, "bbox/train.hdf5"), (val_path, val_meta, "bbox/val.hdf5"), (test_path, test_meta, "bbox/test.hdf5")]

for (paths, metas, outputs) in stuffs:
    writer = HDF5DatasetWriter((len(paths), 96, 96, 3), outputs)
    for path, meta in zip(paths, metas):
        img = cv2.imread(path)
        label = aar_xywh(img, meta)
        img = aar.preprocess(img)
        writer.add([img], [label])
    writer.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [8], line 18
#      16     label = aar_xywh(img, meta)
#      17     img = aar.preprocess(img)
# ---> 18     writer.add([img], [label])
#      19 writer.close()
#
# File ~/Documents/Project/Volleyball/v5/Street_View_House_Numbers-master/utils/hdf5datasetwriter.py:18, in HDF5DatasetWriter.add(self, rows, labels)
#      15 self.buffer["labels"].extend(labels)
#      17 if len(self.buffer["data"]) >= self.bufSize:
# ---> 18     self.flush()
#
# File ~/Documents/Project/Volleyball/v5/Street_View_House_Numbers-master/utils/hdf5datasetwriter.py:24, in HDF5DatasetWriter.flush(self)
#      22 i = self.idx + len(self.buffer["data"])
#      23 self.data[self.idx:i] = self.buffer["data"]
# ---> 24 self.labels[self.idx:i] = self.buffer["labels"]
#      25 self.idx = i
#      26 self.buffer = {"data": [], "labels": []}
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/h5py/_hl/dataset.py:949, in Dataset.__setitem__(self, args, val)
#     946     mshape = val.shape
#     948 # Perform the write, with broadcasting
# --> 949 mspace = h5s.create_simple(selection.expand_shape(mshape))
#     950 for fspace in selection.broadcast(mshape):
#     951     self.id.write(mspace, fspace, val, mtype, dxpl=self._dxpl)
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/h5py/_hl/selections.py:264, in SimpleSelection.expand_shape(self, source_shape)
#     262             eshape.append(t)
#     263         else:
# --> 264             raise TypeError("Can't broadcast %s -> %s" % (source_shape, self.array_shape))  # array shape
#     266 if any([n > 1 for n in remaining_src_dims]):
#     267     # All dimensions from target_shape should either have been popped
#     268     # to match the selection shape, or be 1.
#     269     raise TypeError("Can't broadcast %s -> %s" % (source_shape, self.array_shape))  # array shape
#
# TypeError: Can't broadcast (1000, 4) -> (1000, 6)
